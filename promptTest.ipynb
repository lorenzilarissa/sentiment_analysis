# %%
import pandas as pd
import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
file_path = 'interactions_table_nov_jan.csv'
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#        id  context_id           chat_id      user       role  \
# 0  149355           2  NOC_HEALTH_CHECK       NOC       user
# 1  149356           2  NOC_HEALTH_CHECK  Chat GPT  assistant
# 2  149354           2  NOC_HEALTH_CHECK    Prompt     system
# 3  149351           2  NOC_HEALTH_CHECK    Prompt     system
# 4  149353           2  NOC_HEALTH_CHECK  Chat GPT  assistant
#
#                                              message  \
# 0                                               ping
# 1  Desculpe, mas não entendi sua pergunta. Por fa...
# 2  Seu nome é Bruna. Você é vendedora da Blu, e d...
# 3  Seu nome é Bruna. Você é vendedora da Blu, e d...
# 4  Desculpe, mas não entendi sua pergunta. Por fa...
#
#                          created_at                        updated_at  \
# 0  2024-01-03T09:18:59.707671-03:00  2024-01-03T09:18:59.707671-03:00
# 1  2024-01-03T09:18:59.707671-03:00  2024-01-03T09:18:59.707671-03:00
# 2  2024-01-03T09:18:59.707671-03:00  2024-01-03T09:18:59.707671-03:00
# 3  2024-01-03T09:16:58.099719-03:00  2024-01-03T09:16:58.099719-03:00
# 4  2024-01-03T09:16:58.099719-03:00  2024-01-03T09:16:58.099719-03:00
#
#                     insert_at
# 0  2024-01-03T12:19:01.601805
# 1  2024-01-03T12:19:02.601881
# 2  2024-01-03T12:19:00.601639
# 3  2024-01-03T12:16:59.094278
# 4  2024-01-03T12:17:01.094542

# %%
#select 50 interactions where the user is different from "NOC", "Chat GPT" or "Prompt" and those that does not contains the workd "teste"
df2 = df.loc[~df['user'].isin(["NOC", "Chat GPT", "Prompt", "Felipe undefined"]) 
                & ~df['user'].str.contains("teste") 
                & ~df['message'].str.contains("Não entendi, escolha uma das opções") 
                & ~df['message'].str.contains("Opção Inválida") 
                & ~df['message'].str.contains("Escolha uma das seguintes opções")
                & ~df['message'].str.contains("não entendemos sua mensagem")
                & ~df['message'].str.contains("Departamento Fiscal/Contábil")
                & ~df['message'].str.contains("agradece seu contato")
                & ~df['message'].str.contains("agradece o seu contato")
                & ~df['message'].str.contains("agradece contato")
                & ~df['message'].str.contains("😃")
                & ~df['message'].str.contains("Seja bem-vindo")]

# %%
df3 = df2

# %%
df3.shape
# Out:
# (1533, 9)

# %%
#select only the chat_id group that has more than 20 interactions
df4 = df3.groupby('chat_id').filter(lambda x: len(x) > 10)

# %%
df4.shape
# Out:
# (451, 9)

# %%
df4.head()
# Out:
#           id  context_id               chat_id            user  role  \
# 1591  147765           2  PQRXJ7HVMZFY2LTATN64  Naia undefined  user
# 1593  147762           2  PQRXJ7HVMZFY2LTATN64  Naia undefined  user
# 1598  147759           2  PQRXJ7HVMZFY2LTATN64  Naia undefined  user
# 1599  147756           2  PQRXJ7HVMZFY2LTATN64  Naia undefined  user
# 1686  147669           2  VI76I548ZS4XH0WVKZYJ  Gunshop Brasil  user
#
#                                                 message  \
# 1591                                           Oi Bruna
# 1593                                        falo c quem
# 1598                                                  ?
# 1599  Zero zero possibilidade, ou tem algum cenário ...
# 1686              Olá, quero falar com o suporte da Blu
#
#                             created_at                        updated_at  \
# 1591  2024-01-02T15:50:00.737202-03:00  2024-01-02T15:50:00.737202-03:00
# 1593  2024-01-02T15:49:51.227783-03:00  2024-01-02T15:49:51.227783-03:00
# 1598  2024-01-02T15:49:50.995821-03:00  2024-01-02T15:49:50.995821-03:00
# 1599  2024-01-02T15:49:15.752216-03:00  2024-01-02T15:49:15.752216-03:00
# 1686  2024-01-02T15:15:57.513434-03:00  2024-01-02T15:15:57.513434-03:00
#
#                        insert_at
# 1591  2024-01-02T18:50:03.170355
# 1593  2024-01-02T18:49:53.550174
# 1598  2024-01-02T18:49:53.014602
# 1599   2024-01-02T18:49:19.14508
# 1686  2024-01-02T18:16:00.312992

# %%
#una todos os textos da coluna "message" pelo chat_id em uma única string, e crie uma nova df com essas strings, o chat_id, o user e a data (created_at) da última mensagem

df5 = df4.groupby('chat_id').agg({'message': ' '.join, 'user': 'last', 'created_at': 'last'}).reset_index()

# %%
df5.head()
# Out:
#                                 chat_id  \
# 0                  14VVFZN7R80UNPVA8Q04
# 1                  1DP3MDANB0OGQKASW1OM
# 2                  1OHYT505S3V28ELHD28U
# 3  25472dae-41be-4db5-b465-92b3ee0f285d
# 4                  2S8DYFBPKE8253H7EFPH
#
#                                              message  \
# 0  Empresa Preciso cadastrsr outra empresan __aud...
# 1  O cadastro já deu certo agora só falta pedir a...
# 2  Mais eu sou uma criança Como faço Eu sou uma c...
# 3  Meu salário é 2000,00 e vou tirar 10 dias de f...
# 4  O pagamento em 12x para o cliente tem juros? E...
#
#                               user                        created_at
# 0                        Seoneco 🐸  2023-11-27T13:20:31.515216-03:00
# 1                  Welder Vendedor  2024-01-02T12:35:00.727364-03:00
# 2                  Tulio undefined   2023-11-30T11:02:34.54443-03:00
# 3                  Thaissa Delgado  2023-12-04T19:42:38.730139-03:00
# 4  Cidadedossonhosmoveis undefined  2023-12-07T14:08:58.011084-03:00

# %%
def sentiment_analysis(text):
    prompt = f"""Você é treinado para analisar e detectar o sentimento de um determinado texto.
     Se não tiver certeza de uma resposta, você pode dizer "Não tenho certeza" e recomendar a revisão do usuário manualmente.

     Analise o texto a seguir e determine se o sentimento é: Positivo, Negativo ou Neutro.
    {text}"""

    try:
        response = openai.ChatCompletion.create(
            model="gpt-4",
            messages=[
                {"role": "system", "content": "Você é um assistente prestativo."},
                {"role": "user", "content": prompt}
            ],
            max_tokens=60,
            temperature=0
        )

        sentiment = response.choices[0].message['content'].strip().lower()
        return sentiment
    except Exception as e:
        print("Ocorreu um erro:", e)
        return "Erro"

# %%
#copie e ajuste a função sentment_analysis para retornar o sentimento da mensagem da coluna "message" da df5 de cada chat_id ao invés de analisar o dicionário fictício e adicione uma nova coluna na df5 com o sentimento

df5['sentiment'] = df5['message'].apply(sentiment_analysis)

# %%
df5.head(20)
# Out:
#                                  chat_id  \
# 0                   14VVFZN7R80UNPVA8Q04
# 1                   1DP3MDANB0OGQKASW1OM
# 2                   1OHYT505S3V28ELHD28U
# 3   25472dae-41be-4db5-b465-92b3ee0f285d
# 4                   2S8DYFBPKE8253H7EFPH
# 5                   3HX5TD1K48QBH4IDESXZ
# 6                   3NJQO81D8582E7FQQGMN
# 7   465f7b9f-cf21-4d63-8faf-6f9b253c971a
# 8                   4JH06S7FECE1IXT73JOP
# 9                   6DVB31TR61EW6O61RLSG
# 10                  6U66WQYCNCKQ2GANVFSG
# 11                  AARXFUPLMN15SVO8GEGT
# 12                  CTCXA7V50J8NTO6LDQ8W
# 13                  DT21UXHHZXMECABELPUI
# 14                  DUALU3RZUII0HCZB75YS
# 15                  F0IWDIU1WO2WL254BBNB
# 16                  KNRF15I7UADTMZY2PDGS
# 17                  N4QTWLZ6T43KS48FWH7F
# 18                  O84BLK7D05MUA8HD3JI3
# 19                  OPVO3OQOFO8P8I0FU43M
#
#                                               message  \
# 0   Empresa Preciso cadastrsr outra empresan __aud...
# 1   O cadastro já deu certo agora só falta pedir a...
# 2   Mais eu sou uma criança Como faço Eu sou uma c...
# 3   Meu salário é 2000,00 e vou tirar 10 dias de f...
# 4   O pagamento em 12x para o cliente tem juros? E...
# 5   pode deixar, sua ajuda muito é de pouca avalia...
# 6   atendimento Ja tenho conta, Sim Esse meu amigo...
# 7   qual o link para matricular na totalpass? Qual...
# 8   Como me tornar fornecedor da Blu? Parceiros bl...
# 9   Como faço compra dos fornecedores Qual taxas Q...
# 10  A minha estar cobrando Taxa de aluguel da maqu...
# 11  O cadastro Como faço pra saber se foi aprovado...
# 12  oi entendi e como funciona? qual a cor da cami...
# 13  Ok Vou dar uma verificada! Difícil de acredita...
# 14  Sobre isso Está aí? Flaviane E o valor que ten...
# 15  Como aderir Sim qual seria essa taxa Em um cál...
# 16  Sim Qual o valor mínimo? Valor mínimo de venda...
# 17  Trabalha com blue Qual fábrica de bike Normal ...
# 18  Taxa No caso de um recebimento do débito Com q...
# 19  Taxas link de pagamento Depois dos 6 meses qua...
#
#                                user                        created_at  \
# 0                         Seoneco 🐸  2023-11-27T13:20:31.515216-03:00
# 1                   Welder Vendedor  2024-01-02T12:35:00.727364-03:00
# 2                   Tulio undefined   2023-11-30T11:02:34.54443-03:00
# 3                   Thaissa Delgado  2023-12-04T19:42:38.730139-03:00
# 4   Cidadedossonhosmoveis undefined  2023-12-07T14:08:58.011084-03:00
# 5                   Fernando Bronté  2023-12-13T11:02:26.117422-03:00
# 6                       . undefined  2023-11-23T14:19:51.750014-03:00
# 7                   Larissa Feitosa  2023-11-29T14:43:00.202194-03:00
# 8                    Delaine Baruff  2023-12-19T09:24:47.056425-03:00
# 9               Rr Móveis E Eletros  2023-11-30T10:31:52.699816-03:00
# 10             Irene🦁 5598985529135  2023-12-13T16:54:05.515712-03:00
# 11                Fabiano Mesquista   2023-12-05T14:42:48.06681-03:00
# 12                 Bernard W. Prado  2023-12-01T09:16:01.349879-03:00
# 13               Fernando undefined  2023-12-14T09:39:56.224283-03:00
# 14                     Fogo Central  2023-11-21T10:44:59.376892-03:00
# 15                     🇺🇳 undefined  2023-12-08T13:35:03.335065-03:00
# 16                 Ediane undefined  2023-12-28T13:38:21.321222-03:00
# 17       Fabio Sotero -magnum Tires  2023-12-05T17:46:42.463539-03:00
# 18              Francisco Rodrigues   2023-12-26T14:51:01.51983-03:00
# 19    Mania De Óculos - João Victor  2023-12-05T15:50:39.318651-03:00
#
#                                             sentiment
# 0                                              neutro
# 1                     o sentimento do texto é neutro.
# 2                  o sentimento deste texto é neutro.
# 3                                              neutro
# 4   o sentimento deste texto é neutro. o texto con...
# 5                   o sentimento do texto é negativo.
# 6                                              neutro
# 7                                              neutro
# 8                                              neutro
# 9                                              neutro
# 10                                             neutro
# 11  o sentimento do texto é neutro. o texto é comp...
# 12                    o sentimento do texto é neutro.
# 13                    o sentimento do texto é neutro.
# 14                                             neutro
# 15                                             neutro
# 16                                             neutro
# 17                                             neutro
# 18                                             neutro
# 19                                             neutro

# %%
#mostre o texto completo da coluna "message" da df5 onde o chat_id é 3HX5TD1K48QBH4IDESXZ

df5.loc[df5['chat_id'] == '3HX5TD1K48QBH4IDESXZ', 'message'].iloc[0]
# Out:
# 'pode deixar, sua ajuda muito é de pouca avalia pode deixar, sua ajuda muito é de pouca avalia Sistema para da a informação que já existe um usuario com um dos dados informados já informei várias vezes o que esta acontecendo mas nao ´parece Péssimo serviço Repete sempre a mesma coisa Então ajuda da a informação que já existe um usuario com um dos dados informados da a informação que já existe um usuario com um dos dados informados já tentei mas não avança preciso cadastrar outro email e usuario da conta blu'

# %%
# Example usage
input_text = "Estou feliz com o produto!"
sentiment = sentiment_analysis(input_text)
print(input_text, ": Sentiment is:", sentiment)

# %%
# Example usage
input_text = "Não gostei, deu muito problema!"
sentiment = sentiment_analysis(input_text)
print(input_text, ": Sentiment is:", sentiment)
# Out:
# Não gostei, deu muito problema! : Sentiment is: o sentimento do texto é negativo.

# %%
# Out:
# Estou feliz com o produto! : Sentiment is: o sentimento do texto é positivo.
