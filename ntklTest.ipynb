# %%
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
# Substitua o URL abaixo pelo URL do arquivo CSV no seu repositório do GitHub
github_csv_url = 'C:\\Users\\larissa.lorenzi\\Git\\ai-notebooks\\SentimentAnalysisBlubot/chat_data.csv'

# Use o pandas para ler o arquivo CSV a partir do URL
df = pd.read_csv(github_csv_url)

# %%
nltk.download('vader_lexicon')
sid = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\larissa.lorenzi\AppData\Roaming\nltk_data...

# %%
# Vamos criar uma nova coluna chamada "sentiment_score" para armazenar os valores de sentimento
df['sentiment_score'] = df['message'].apply(lambda message: sid.polarity_scores(message)['compound'])

# %%
df = df.sort_values(by='sentiment_score', ascending=False)
df.head(20)
# Out:
#          id  context_id                               chat_id  \
# 1293   4383           2                  3Y7DRGEWAYRV7HPVGGFV
# 1294   4386           2                  3Y7DRGEWAYRV7HPVGGFV
# 2261  15111           4                             licenças1
# 1000   2616           2                  G4IA5T76UH2AYH6WKEH5
# 1981  11505           2                  P2XPZZ31K5K8ET3PONWU
# 1062   2745           2                  IBDSKZI67R6UK6JM84JE
# 685    4854           2                  W10M425XNJ7QHR820WJU
# 797    1965           2                  HZY71OP88F7UXLEV4C7E
# 75      162           1                  CTCXA7V50J8NTO6LDQ8W
# 1010   2634           2                  G4IA5T76UH2AYH6WKEH5
# 719    1761           2                  4REYKAQ73PH5781Y5C6U
# 485    4725           2                  GTRWDZMFAHF253EBD0IV
# 213     627           1                  4REYKAQ73PH5781Y5C6U
# 98      225           1  72e141f9-d4dd-4108-9001-c857cc496635
# ...

# %%
def analyse_sentment(message):
    sentment = sid.polarity_scores(message)
    if sentment['compound'] >= 0.05:
        return 'Positivo'
    elif sentment['compound'] <= -0.05:
        return 'Negativo'
    else:
        return 'Neutro'

# %%
df['sentment'] = df['message'].apply(analyse_sentment)

# %%
df[df['sentment'] == 'negative'].head(30)
# Out:
#          id  context_id                               chat_id  \
# 1387   4674           2                  CG6GB85VN5IOD7IEA1S6
# 1383   4662           2                  CG6GB85VN5IOD7IEA1S6
# 581    1374           1  c6d65a65-7862-455c-94cd-cd92316c9972
# 432    4191           2                  IPER3DEIEDDBY6JA5XSV
# 1451  16134           4                           transporte1
# 2377  15633           4                                 vida1
# 2370  15630           4                                 vida1
# 2322  15606           4                                 vida1
# 2364  15627           4                                 vida1
# 1470  15762           4                                ponto1
# 2359  15624           4                                 vida1
# 1439  15753           4                                ponto1
# 494    4254           5  72e141f9-d4dd-4108-9001-c857cc496635
# 1478  15765           4                                ponto1
# ...
